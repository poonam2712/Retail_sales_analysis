# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('retail_sales_dataset.csv')
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  11/24/2023     CUST001    Male   34           Beauty
# 1                 2   2/27/2023     CUST002  Female   26         Clothing
# 2                 3   1/13/2023     CUST003    Male   50      Electronics
# 3                 4   5/21/2023     CUST004    Male   37         Clothing
# 4                 5    5/6/2023     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996   5/16/2023     CUST996    Male   62         Clothing
# 996             997  11/17/2023     CUST997    Male   52           Beauty
# 997             998  10/29/2023     CUST998  Female   23           Beauty
# 998             999   12/5/2023     CUST999  Female   36      Electronics
# 999            1000   4/12/2023    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 0           3              50           150
# 1           2             500          1000
# 2           1              30            30
# 3           1             500           500
# 4           2              50           100
# ..        ...             ...           ...
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120
#
# [1000 rows x 9 columns]

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  11/24/2023     CUST001    Male   34           Beauty
# 1               2   2/27/2023     CUST002  Female   26         Clothing
# 2               3   1/13/2023     CUST003    Male   50      Electronics
# 3               4   5/21/2023     CUST004    Male   37         Clothing
# 4               5    5/6/2023     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996   5/16/2023     CUST996    Male   62         Clothing
# 996             997  11/17/2023     CUST997    Male   52           Beauty
# 997             998  10/29/2023     CUST998  Female   23           Beauty
# 998             999   12/5/2023     CUST999  Female   36      Electronics
# 999            1000   4/12/2023    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %%
print("The number of records of rows in the data is:",df.shape[0])
print("The number of records of columns in the data is:",df.shape[1])
# Out:
# The number of records of rows in the data is: 1000
# The number of records of columns in the data is: 9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
df.describe(include="O")
# Out:
#              Date Customer ID  Gender Product Category
# count        1000        1000    1000             1000
# unique        345        1000       2                3
# top     5/16/2023    CUST1000  Female         Clothing
# freq           11           1     510              351

# %% [markdown]
# pandas will look only at the columns whose datatype is "O" (object). Then it provides summary stats such as:
#
# count – Number of non-missing values
#
# unique – How many distinct values the column has
#
# top – The most frequent value
#
# freq – The frequency of that most frequent value

# %%
#check for inconsistent values
for i in df.columns:
    if df[i].nunique() != len(df[i]):
        print(i)
        print(df[i].unique())
        print("-"*100)
        print()
# Out:
# Date
# ['11/24/2023' '2/27/2023' '1/13/2023' '5/21/2023' '5/6/2023' '4/25/2023'
#  '3/13/2023' '2/22/2023' '12/13/2023' '10/7/2023' '2/14/2023' '10/30/2023'
#  '8/5/2023' '1/17/2023' '1/16/2023' '2/17/2023' '4/22/2023' '4/30/2023'
#  '9/16/2023' '11/5/2023' '1/14/2023' '10/15/2023' '4/12/2023' '11/29/2023'
#  '12/26/2023' '8/3/2023' '4/23/2023' '8/18/2023' '10/29/2023' '5/23/2023'
#  '1/4/2023' '3/23/2023' '12/24/2023' '6/24/2023' '3/21/2023' '4/21/2023'
#  '6/22/2023' '7/14/2023' '2/19/2023' '7/3/2023' '6/26/2023' '11/6/2023'
#  '5/16/2023' '1/23/2023' '8/24/2023' '10/2/2023' '3/5/2023' '7/13/2023'
#  '2/10/2023' '10/10/2023' '5/31/2023' '11/18/2023' '11/13/2023' '7/5/2023'
#  '10/23/2023' '4/9/2023' '12/27/2023' '2/5/2023' '1/24/2023' '12/5/2023'
#  '4/27/2023' '5/29/2023' '2/21/2023' '8/21/2023' '11/22/2023' '7/6/2023'
#  '3/25/2023' '7/9/2023' '7/1/2023' '4/18/2023' '12/10/2023' '5/17/2023'
#  '12/16/2023' '11/28/2023' '2/6/2023' '11/8/2023' '3/29/2023' '10/1/2023'
#  '8/25/2023' '5/19/2023' '12/19/2023' '10/13/2023' '12/17/2023'
#  '6/16/2023' '1/29/2023' '4/28/2023' '6/11/2023' '7/25/2023' '5/18/2023'
#  '2/3/2023' '4/19/2023' '10/18/2023' '12/2/2023' '9/13/2023' '7/22/2023'
#  '11/26/2023' '8/23/2023' '3/15/2023' '5/7/2023' '10/3/2023' '5/15/2023'
#  '10/27/2023' '8/8/2023' '10/26/2023' '7/24/2023' '3/12/2023' '9/18/2023'
#  '9/10/2023' '2/16/2023' '1/25/2023' '2/26/2023' '3/20/2023' '12/15/2023'
#  '11/2/2023' '2/2/2023' '7/17/2023' '7/15/2023' '8/28/2023' '9/28/2023'
#  '5/9/2023' '10/11/2023' '1/6/2023' '2/28/2023' '11/25/2023' '8/11/2023'
#  '3/22/2023' '1/2/2023' '9/14/2023' '4/2/2023' '9/17/2023' '2/24/2023'
#  '11/17/2023' '6/2/2023' '7/11/2023' '3/24/2023' '10/4/2023' '9/29/2023'
#  '1/1/2023' '11/3/2023' '6/15/2023' '9/8/2023' '1/10/2023' '6/7/2023'
#  '5/3/2023' '1/30/2023' '5/4/2023' '2/13/2023' '9/6/2023' '9/30/2023'
#  '3/6/2023' '3/7/2023' '12/4/2023' '9/1/2023' '10/9/2023' '3/26/2023'
#  '11/7/2023' '12/20/2023' '4/13/2023' '1/1/2024' '6/9/2023' '8/13/2023'
#  '9/22/2023' '8/20/2023' '3/3/2023' '4/26/2023' '6/23/2023' '1/11/2023'
#  '12/29/2023' '11/20/2023' '1/31/2023' '2/4/2023' '6/19/2023' '9/21/2023'
#  '5/2/2023' '12/9/2023' '4/20/2023' '3/9/2023' '10/20/2023' '8/31/2023'
#  '5/5/2023' '7/28/2023' '4/8/2023' '2/18/2023' '8/9/2023' '7/30/2023'
#  '1/28/2023' '12/11/2023' '12/1/2023' '11/27/2023' '2/20/2023' '2/1/2023'
#  '7/26/2023' '2/25/2023' '5/8/2023' '4/4/2023' '2/8/2023' '8/15/2023'
#  '1/26/2023' '11/30/2023' '1/8/2023' '3/27/2023' '9/4/2023' '7/19/2023'
#  '5/27/2023' '12/23/2023' '10/12/2023' '9/7/2023' '6/1/2023' '10/24/2023'
#  '10/5/2023' '6/10/2023' '9/2/2023' '9/15/2023' '2/11/2023' '4/6/2023'
#  '11/1/2023' '12/12/2023' '5/1/2023' '10/19/2023' '1/21/2023' '11/14/2023'
#  '12/3/2023' '10/17/2023' '9/25/2023' '5/14/2023' '4/15/2023' '6/3/2023'
#  '2/7/2023' '1/5/2023' '11/15/2023' '10/16/2023' '6/28/2023' '5/26/2023'
#  '10/6/2023' '6/4/2023' '11/10/2023' '12/8/2023' '12/6/2023' '2/23/2023'
#  '3/10/2023' '3/1/2023' '5/20/2023' '5/25/2023' '6/25/2023' '12/18/2023'
#  '11/21/2023' '1/27/2023' '5/22/2023' '6/20/2023' '3/8/2023' '11/23/2023'
#  '12/28/2023' '8/7/2023' '3/18/2023' '1/19/2023' '3/17/2023' '1/22/2023'
#  '10/14/2023' '4/1/2023' '7/31/2023' '1/20/2023' '8/29/2023' '4/24/2023'
#  '6/29/2023' '6/6/2023' '6/18/2023' '12/14/2023' '1/15/2023' '10/25/2023'
#  '8/12/2023' '9/19/2023' '5/11/2023' '9/24/2023' '4/11/2023' '12/7/2023'
#  '11/16/2023' '6/8/2023' '7/29/2023' '6/17/2023' '8/4/2023' '3/31/2023'
#  '11/12/2023' '7/27/2023' '10/8/2023' '6/5/2023' '6/14/2023' '8/27/2023'
#  '3/28/2023' '6/21/2023' '11/9/2023' '8/22/2023' '8/1/2023' '11/19/2023'
#  '10/22/2023' '4/10/2023' '7/16/2023' '9/11/2023' '1/3/2023' '8/6/2023'
#  '9/23/2023' '8/26/2023' '3/4/2023' '6/12/2023' '8/17/2023' '8/19/2023'
#  '5/13/2023' '8/14/2023' '2/9/2023' '6/13/2023' '3/19/2023' '4/29/2023'
#  '12/22/2023' '4/16/2023' '6/30/2023' '7/21/2023' '10/31/2023' '2/12/2023'
#  '3/11/2023' '5/10/2023' '12/25/2023' '5/12/2023' '7/8/2023' '7/12/2023'
#  '7/23/2023' '11/4/2023' '6/27/2023' '1/7/2023' '8/10/2023' '9/5/2023'
#  '5/24/2023' '12/31/2023' '9/9/2023' '1/9/2023' '12/21/2023' '4/5/2023'
#  '9/26/2023' '7/4/2023' '5/30/2023' '10/21/2023' '9/3/2023' '3/2/2023'
#  '8/2/2023' '4/17/2023' '3/30/2023' '5/28/2023']
# ----------------------------------------------------------------------------------------------------
#
# Gender
# ['Male' 'Female']
# ----------------------------------------------------------------------------------------------------
#
# Age
# [34 26 50 37 30 45 46 63 52 23 35 22 64 42 19 27 47 62 18 49 28 38 43 39
#  44 51 58 48 55 20 40 54 36 31 21 57 25 56 29 61 32 41 59 60 33 53 24]
# ----------------------------------------------------------------------------------------------------
#
# Product Category
# ['Beauty' 'Clothing' 'Electronics']
# ----------------------------------------------------------------------------------------------------
#
# Quantity
# [3 2 1 4]
# ----------------------------------------------------------------------------------------------------
#
# Price per Unit
# [ 50 500  30  25 300]
# ----------------------------------------------------------------------------------------------------
#
# Total Amount
# [ 150 1000   30  500  100   50  600  200   75 1500  120 2000  900  300
#  1200   90   25   60]
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# We will check whether the column contains duplicate values.
# i is iterating variable for columns
#
# df[i].nunique() → number of unique values in column i
#
# len(df[i]) → total number of rows
#
# If these two numbers are not equal, then the column has at least one duplicate value

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Month']=df['Date'].dt.month_name()
df['Year']=df['Date'].dt.year
df['Days']=df['Date'].dt.day_name()
df['MonthDate']=df['Date'].dt.day
df.head()
# Out:
#    Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0               1 2023-11-24     CUST001    Male   34           Beauty
# 1               2 2023-02-27     CUST002  Female   26         Clothing
# 2               3 2023-01-13     CUST003    Male   50      Electronics
# 3               4 2023-05-21     CUST004    Male   37         Clothing
# 4               5 2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount     Month  Year      Days  MonthDate
# 0         3              50           150  November  2023    Friday         24
# 1         2             500          1000  February  2023    Monday         27
# 2         1              30            30   January  2023    Friday         13
# 3         1             500           500       May  2023    Sunday         21
# 4         2              50           100       May  2023  Saturday          6

# %%
bins=[18,30,40,50,60,70]
label=['18-29','30-39','40-49','50-59','60+']
df['age_group']=pd.cut(df['Age'],labels=label,bins=bins)
df.head()
# Out:
#    Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0               1 2023-11-24     CUST001    Male   34           Beauty
# 1               2 2023-02-27     CUST002  Female   26         Clothing
# 2               3 2023-01-13     CUST003    Male   50      Electronics
# 3               4 2023-05-21     CUST004    Male   37         Clothing
# 4               5 2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount     Month  Year      Days  \
# 0         3              50           150  November  2023    Friday
# 1         2             500          1000  February  2023    Monday
# 2         1              30            30   January  2023    Friday
# 3         1             500           500       May  2023    Sunday
# 4         2              50           100       May  2023  Saturday
#
#    MonthDate age_group
# 0         24     30-39
# 1         27     18-29
# 2         13     40-49
# 3         21     30-39
# 4          6     18-29

# %% [markdown]
# **pd.cut() divides your Age column into the defined bins and assigns the appropriate label.
# This is used for age segmentation, which is very important in:
# Retail analysis,Customer segmentation and Marketing**

# %% [markdown]
# ### 1. Analyze the relationship between age, gender, and spending behavior.

# %%
#
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x='age_group',y='Total Amount',hue='Gender',palette='Set2')

plt.title("Spending Distrubution by Age group and gender")
plt.xlabel("Age Group")
plt.ylabel("Total Amount")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Conclusion:
#
# 1. Spending varies significantly with age
#
# Younger age groups (especially 18–29 and 30–39) show higher variability in spending, indicating a mix of low and very high spenders.
#
# Middle-aged groups (40–49 and 50–59) tend to have more stable but still relatively high spending, suggesting consistent purchasing power.
#
# The 60+ age group generally shows lower spending as comapre to other age groups..though some high-spending outliers still exist.
#
# 2. Gender differences are evident across age groups
#
# Females generally have higher median spending than males in most age groups, particularly in 30–39 and 50–59, suggesting stronger or more frequent consumption in these ranges.
#
# Males have higher Total spending in age groups 40-49,60+. In 18-29 age groups Both male and female categories are having same total spending..
#
# 3. Presence of outliers across all groups
#
# Their are some outliers in age group 30-39,40-49,50-59,60+..showing that both male and female can create high spending amount..

# %% [markdown]
# ### 2. Compare average spending across different age groups and genders.

# %%
spending_summary=df.groupby(['age_group','Gender'])['Total Amount'].agg(['mean']).reset_index()
print(spending_summary)
# Out:
#   age_group  Gender        mean
# 0     18-29  Female  491.031746
# 1     18-29    Male  475.079365
# 2     30-39  Female  521.546392
# 3     30-39    Male  472.500000
# 4     40-49  Female  387.715517
# 5     40-49    Male  464.952381
# 6     50-59  Female  465.818966
# 7     50-59    Male  442.788462
# 8       60+  Female  319.761905
# 9       60+    Male  388.137255
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19368\401101403.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   spending_summary=df.groupby(['age_group','Gender'])['Total Amount'].agg(['mean']).reset_index()

# %%
plt.figure(figsize=(15,8))

k=sns.barplot(data=df,x='age_group',y='Total Amount',hue='Gender',errorbar=None)
k.bar_label(k.containers[0])
k.bar_label(k.containers[1])

plt.title('Avarage spending by Age Group and Gender')
plt.xlabel('Age Group')
plt.ylabel('avarage spending')
plt.legend()
plt.show()

# %% [markdown]
# ### 3.Identify trends in sales over different months, seasons, and years.

# %%
month_order=['January','February','March','April','May','June','July','August','September','October','November','December']

# convert the month columns into an ordered categorical type
df['Month']=pd.Categorical(df['Month'],categories=month_order,ordered=True)
df['Month']
# Out:
# 0      November
# 1      February
# 2       January
# 3           May
# 4           May
#          ...
# 995         May
# 996    November
# 997     October
# 998    December
# 999       April
# Name: Month, Length: 1000, dtype: category
# Categories (12, object): ['January' < 'February' < 'March' < 'April' ... 'September' < 'October' < 'November' < 'December']

# %% [markdown]
# ### Categorical():-
# pd.Categorical() turns a column into a special data type called category, which can be:
#
# Ordered (like months, sizes, grades)
#
# Unordered (like product categories, store types)
#
# We used Categorical() because months are not alphabetical. They have a natural order.
#
# Alphabetical sort gives:
#
# April, August, December, February…
#
# But time-series analysis requires:
#
# January → February → March → … → December

# %%
day_order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
df['Days']=pd.Categorical(df['Days'],categories=day_order,ordered=True)
df["Days"]
# Out:
# 0         Friday
# 1         Monday
# 2         Friday
# 3         Sunday
# 4       Saturday
#          ...
# 995      Tuesday
# 996       Friday
# 997       Sunday
# 998      Tuesday
# 999    Wednesday
# Name: Days, Length: 1000, dtype: category
# Categories (7, object): ['Monday' < 'Tuesday' < 'Wednesday' < 'Thursday' < 'Friday' < 'Saturday' < 'Sunday']

# %%
df['Season']=df['Month'].map({
    'December': 'Winter', 'January': 'Winter', 'February': 'Winter',
    "March": 'Summer', "April": 'Summer', "May": 'Summer',
    "June": 'Monsoon', "July":'Monsoon', "August": 'Monsoon',
    "September": 'Monsoon', "October": 'Post-Monsoon', "November": 'Post-Monsoon'
})
df
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0                 1 2023-11-24     CUST001    Male   34           Beauty
# 1                 2 2023-02-27     CUST002  Female   26         Clothing
# 2                 3 2023-01-13     CUST003    Male   50      Electronics
# 3                 4 2023-05-21     CUST004    Male   37         Clothing
# 4                 5 2023-05-06     CUST005    Male   30           Beauty
# ..              ...        ...         ...     ...  ...              ...
# 995             996 2023-05-16     CUST996    Male   62         Clothing
# 996             997 2023-11-17     CUST997    Male   52           Beauty
# 997             998 2023-10-29     CUST998  Female   23           Beauty
# 998             999 2023-12-05     CUST999  Female   36      Electronics
# 999            1000 2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount     Month  Year       Days  \
# 0           3              50           150  November  2023     Friday
# 1           2             500          1000  February  2023     Monday
# 2           1              30            30   January  2023     Friday
# 3           1             500           500       May  2023     Sunday
# 4           2              50           100       May  2023   Saturday
# ..        ...             ...           ...       ...   ...        ...
# 995         1              50            50       May  2023    Tuesday
# 996         3              30            90  November  2023     Friday
# 997         4              25           100   October  2023     Sunday
# 998         3              50           150  December  2023    Tuesday
# 999         4              30           120     April  2023  Wednesday
#
#      MonthDate age_group        Season
# 0           24     30-39  Post-Monsoon
# 1           27     18-29        Winter
# 2           13     40-49        Winter
# 3           21     30-39        Summer
# 4            6     18-29        Summer
# ..         ...       ...           ...
# 995         16       60+        Summer
# 996         17     50-59  Post-Monsoon
# 997         29     18-29  Post-Monsoon
# 998          5     30-39        Winter
# 999         12     40-49        Summer
#
# [1000 rows x 15 columns]

# %% [markdown]
# **The .map() function reads each value in the "Month" column and replaces it with a corresponding value from the dictionary you provided**

# %%
fig,axes=plt.subplots(nrows=2,ncols=1,figsize=(15,6))

sns.lineplot(data=df,x='Month',y='Total Amount',marker="o",errorbar=None,ax=(axes[0]))
plt.title("Trends of sales over dofferent months")

b=sns.barplot(data=df,x="Season",y='Total Amount',hue='Product Category',errorbar=None)
b.bar_label(b.containers[0])
b.bar_label(b.containers[1])
b.bar_label(b.containers[2])

#sns.lineplot(data=df,x='Season',y='Total Amount',hue='Product Category',errorbar=None,ax=(axes[1]))
plt.title("Trends of sales over different Seasons")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.Determine the most popular product categories by sales volume and revenue.

# %%
#most popular product  categories by values sales valoume
sales_volume=df.groupby('Product Category')['Quantity'].sum().reset_index()
sales_volume
# Out:
#   Product Category  Quantity
# 0           Beauty       771
# 1         Clothing       894
# 2      Electronics       849

# %%
sales_volume=sales_volume.sort_values(by='Quantity',ascending=False)
sales_volume
# Out:
#   Product Category  Quantity
# 1         Clothing       894
# 2      Electronics       849
# 0           Beauty       771

# %%
plt.figure(figsize=(12,6))
k=sns.barplot(data=sales_volume,x='Product Category',y='Quantity',palette='viridis')
for i in k.containers:
    k.bar_label(i)

plt.title("top Product Categories by Sales Volume",fontsize=16)
plt.xlabel("Units Sold")
plt.ylabel("Product Category")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19368\2399717018.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   k=sns.barplot(data=sales_volume,x='Product Category',y='Quantity',palette='viridis')

# %% [markdown]
# ### Top product Catergories by Revenue

# %%
if 'Revenue' not in df.columns:
    df['Revenue']=df['Quantity']* df['Price per Unit']

revenue=df.groupby('Product Category')['Revenue'].sum().reset_index()
revenue
# Out:
#   Product Category  Revenue
# 0           Beauty   143515
# 1         Clothing   155580
# 2      Electronics   156905

# %%
revenue=revenue.sort_values(by='Revenue',ascending=False)
revenue
# Out:
#   Product Category  Revenue
# 2      Electronics   156905
# 1         Clothing   155580
# 0           Beauty   143515

# %%
plt.figure(figsize=(12,6))
ax=sns.barplot(
    data=revenue,
    x='Product Category',
    y='Revenue',
    palette='magma'
)

for i in ax.containers:
    ax.bar_label(i)

'''ax.bar_label(ax.containers[0],padding=3)
ax.bar_label(ax.containers[1],padding=3)
ax.bar_label(ax.containers[2],padding=3''')

plt.title('Top Product Categories by Revenue',fontsize=16)
plt.xticks(rotation=45)
plt.ylabel('Revenue')
plt.xlabel('Product category')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19368\2626280176.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(

# %% [markdown]
# ### 5. Analyze customer demographics for each product category

# %% [markdown]
# #### Gender Distribution per Product Category

# %%
gender_dist=df.groupby(['Product Category','Gender']).size().unstack()
print(gender_dist)
# Out:
# Gender            Female  Male
# Product Category
# Beauty               166   141
# Clothing             174   177
# Electronics          170   172

# %% [markdown]
# **unstack() is used when you group by more than one column and want to convert one of those grouping levels into columns instead of keeping everything in a long format.**
#
# 1. groupby() → produces stacked multi-index output
# 2. unstack() → converts it into a pivot-table-like structure

# %%
plt.figure(figsize=(10,5))
b=sns.countplot(data=df,x='Product Category',hue='Gender')
b.bar_label(b.containers[0])
b.bar_label(b.containers[1])

plt.title("Gender Distribution by Product Category")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### B. Age Group distribution per Product category

# %%
age_group_dist=df.groupby(['Product Category','age_group']).size().unstack()
print(age_group_dist)
# Out:
# age_group         18-29  30-39  40-49  50-59  60+
# Product Category
# Beauty               88     56     66     62   26
# Clothing             81     69     81     80   33
# Electronics          83     68     74     78   34
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19368\3111856172.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_group_dist=df.groupby(['Product Category','age_group']).size().unstack()

# %%
plt.figure(figsize=(10,5))
k=sns.countplot(data=df,x='Product Category',hue='age_group')

for i in k.containers:
    k.bar_label(i)

plt.title("Age_group distribution by Product Category")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### c.Avarage age of customers by Category

# %%
avg_age=df.groupby('Product Category')['Age'].mean()
print(avg_age)
# Out:
# Product Category
# Beauty         40.371336
# Clothing       41.948718
# Electronics    41.736842
# Name: Age, dtype: float64

# %% [markdown]
# #### Final Summery

# %%
# age Group VS product Category Heatmap
pivot=df.pivot_table(
    values='Customer ID',
    index='age_group',
    columns='Product Category',
    aggfunc='count'
)
pivot

sns.heatmap(pivot,annot=True,cmap='magma')
plt.title("Age Group VS Product Category Heatmap")

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19368\460037491.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot=df.pivot_table(

# %% [markdown]
# ### 6. Compare purchasing behavior during different seasons.

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount',
#        'Month', 'Year', 'Days', 'MonthDate', 'age_group', 'Season', 'Revenue'],
#       dtype='object')

# %%
plt.figure(figsize=(15,8))

k=sns.barplot(data=df,x='Season',y='Quantity',estimator=sum,hue="Product Category",errorbar=None)

for i in k.containers:
    k.bar_label(i)

plt.title("Seasonal Purchasing Behavior byProduct Category")
plt.ylabel("Total Quantity Purchased")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=df,x='Season',y='Quantity',marker='o',estimator=sum,errorbar=None,hue='Product Category')
plt.title("trends of sales over different Season")
# Out:
# Text(0.5, 1.0, 'trends of sales over different Season')

# %% [markdown]
# ### 7.Identify customer groups that buy in bulk vs. small quantities.

# %%
df
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0                 1 2023-11-24     CUST001    Male   34           Beauty
# 1                 2 2023-02-27     CUST002  Female   26         Clothing
# 2                 3 2023-01-13     CUST003    Male   50      Electronics
# 3                 4 2023-05-21     CUST004    Male   37         Clothing
# 4                 5 2023-05-06     CUST005    Male   30           Beauty
# ..              ...        ...         ...     ...  ...              ...
# 995             996 2023-05-16     CUST996    Male   62         Clothing
# 996             997 2023-11-17     CUST997    Male   52           Beauty
# 997             998 2023-10-29     CUST998  Female   23           Beauty
# 998             999 2023-12-05     CUST999  Female   36      Electronics
# 999            1000 2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount     Month  Year       Days  \
# 0           3              50           150  November  2023     Friday
# 1           2             500          1000  February  2023     Monday
# 2           1              30            30   January  2023     Friday
# 3           1             500           500       May  2023     Sunday
# 4           2              50           100       May  2023   Saturday
# ..        ...             ...           ...       ...   ...        ...
# 995         1              50            50       May  2023    Tuesday
# 996         3              30            90  November  2023     Friday
# 997         4              25           100   October  2023     Sunday
# 998         3              50           150  December  2023    Tuesday
# 999         4              30           120     April  2023  Wednesday
#
#      MonthDate age_group        Season  Revenue
# 0           24     30-39  Post-Monsoon      150
# 1           27     18-29        Winter     1000
# 2           13     40-49        Winter       30
# 3           21     30-39        Summer      500
# 4            6     18-29        Summer      100
# ..         ...       ...           ...      ...
# 995         16       60+        Summer       50
# 996         17     50-59  Post-Monsoon       90
# 997         29     18-29  Post-Monsoon      100
# 998          5     30-39        Winter      150
# 999         12     40-49        Summer      120
#
# [1000 rows x 16 columns]

# %%
df['qty_status']=df['Quantity'].apply(lambda x: 'bulk quantities' if x in[3,4] else 'small quantities')
df['qty_status']
# Out:
# 0       bulk quantities
# 1      small quantities
# 2      small quantities
# 3      small quantities
# 4      small quantities
#              ...
# 995    small quantities
# 996     bulk quantities
# 997     bulk quantities
# 998     bulk quantities
# 999     bulk quantities
# Name: qty_status, Length: 1000, dtype: object

# %%
df1=df['qty_status'].value_counts()
df1
# Out:
# qty_status
# bulk quantities     504
# small quantities    496
# Name: count, dtype: int64

# %%
df.groupby(['age_group','qty_status']).size().reset_index(name='count')
#df.groupby(['age_group','qty_status'])['qty_status'].count().reset_index(name='count')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_19368\266880026.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['age_group','qty_status']).size().reset_index(name='count')
#   age_group        qty_status  count
# 0     18-29   bulk quantities    128
# 1     18-29  small quantities    124
# 2     30-39   bulk quantities    106
# 3     30-39  small quantities     87
# 4     40-49   bulk quantities    106
# 5     40-49  small quantities    115
# 6     50-59   bulk quantities    111
# 7     50-59  small quantities    109
# 8       60+   bulk quantities     41
# 9       60+  small quantities     52

# %%
fig, axes=plt.subplots(2,1,figsize=(6,10))

#sns.countplot(data=df,x='qty_status',ax=axes[0])
axes[0].pie(x=df1.values,labels=df1.index,
            autopct='%i%%',
            startangle=90,explode=(0,0.1))
axes[0].set_title("Bulk Vs Small Quantity Purcases")

k=sns.countplot(data=df,x='age_group',hue='qty_status',ax=axes[1])
for i in k.containers:
    k.bar_label(i)

plt.show()

# %% [markdown]
# startangle rotates the pie chart by a specified angle so that the first slice starts from that position.The angle is measured counter-clockwise from the x-axis (3 o’clock position).
#
# Default value is 0.
